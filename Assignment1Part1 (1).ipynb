# %%
import pandas as pd

# %%
df = pd.read_csv("Traffic_Crashes_-_Crashes.csv")

# %%
df.head()
# Out:
#                                      CRASH_RECORD_ID CRASH_DATE_EST_I  \
# 0  00a530520c84927490b597a6220ff3f2a3347472ef3086...              NaN
# 1  027187f52f9cac9ec542f1dda3a9ca8804db1fc2d2a386...              NaN
# 2  204c3ca48ff3cdf0737e7f10b54ef5f8c49fbe30b5e53e...              NaN
# 3  0173d218723a1d608d77b7142ca9b9a4afd7463e824162...                Y
# 4  0386ef145c229cc3cb409c51d647b6496ab660104f16c7...              NaN
#
#                CRASH_DATE  POSTED_SPEED_LIMIT TRAFFIC_CONTROL_DEVICE  \
# 0  01/15/2025 01:50:00 PM                  30            NO CONTROLS
# 1  05/31/2020 01:13:00 AM                  30         TRAFFIC SIGNAL
# 2  12/04/2024 05:39:00 PM                  30                UNKNOWN
# 3  09/23/2023 10:39:00 AM                  30         TRAFFIC SIGNAL
# 4  06/26/2023 01:54:00 PM                  30            NO CONTROLS
#
#        DEVICE_CONDITION WEATHER_CONDITION      LIGHTING_CONDITION  \
# 0           NO CONTROLS             CLEAR                DAYLIGHT
# 1               UNKNOWN             CLEAR  DARKNESS, LIGHTED ROAD
# 2               UNKNOWN              RAIN  DARKNESS, LIGHTED ROAD
# 3  FUNCTIONING PROPERLY           UNKNOWN                 UNKNOWN
# 4  FUNCTIONING PROPERLY             CLEAR                DAYLIGHT
#
#        FIRST_CRASH_TYPE   TRAFFICWAY_TYPE  ...  INJURIES_NON_INCAPACITATING  \
# 0          FIXED OBJECT              RAMP  ...                          0.0
# 1               TURNING          FOUR WAY  ...                          0.0
# 2               TURNING       NOT DIVIDED  ...                          0.0
# 3  PARKED MOTOR VEHICLE       NOT DIVIDED  ...                          0.0
# 4               TURNING  CENTER TURN LANE  ...                          0.0
#
#   INJURIES_REPORTED_NOT_EVIDENT INJURIES_NO_INDICATION INJURIES_UNKNOWN  \
# 0                           0.0                    1.0              0.0
# 1                           0.0                    4.0              0.0
# 2                           0.0                    2.0              0.0
# 3                           0.0                    1.0              0.0
# 4                           0.0                    3.0              0.0
#
#   CRASH_HOUR CRASH_DAY_OF_WEEK CRASH_MONTH   LATITUDE  LONGITUDE  \
# 0         13                 4           1  41.816073 -87.656743
# 1          1                 1           5  41.878326 -87.701280
# 2         17                 4          12        NaN        NaN
# 3         10                 7           9  42.010386 -87.670011
# 4         13                 2           6  41.873435 -87.666434
#
#                                    LOCATION
# 0  POINT (-87.656742699936 41.816073475493)
# 1  POINT (-87.701279794376 41.878326229569)
# 2                                       NaN
# 3   POINT (-87.67001097385 42.010385766289)
# 4    POINT (-87.666433681443 41.8734345658)
#
# [5 rows x 48 columns]

# %%
df.tail()
# Out:
#                                           CRASH_RECORD_ID CRASH_DATE_EST_I  \
# 923421  00580c38c361fe6da401a2a6b96f381a08f3a6811f18c7...              NaN
# 923422  4f4333f00f578df2ffc68daa7a1177143340d8d899b83c...              NaN
# 923423  5ac09423aa9016c9755f1cace10a067fcab2648f18577c...              NaN
# 923424  338dda3383526a914c74060bc7869511f7071da6d922ca...              NaN
# 923425  bfa8377168b8dc75b4a09bf627b4e28fc77f465911c99b...              NaN
#
#                     CRASH_DATE  POSTED_SPEED_LIMIT TRAFFIC_CONTROL_DEVICE  \
# 923421  01/29/2025 07:25:00 PM                  30            NO CONTROLS
# 923422  01/29/2025 09:27:00 AM                  30         TRAFFIC SIGNAL
# 923423  01/29/2025 07:08:00 PM                  30         TRAFFIC SIGNAL
# 923424  06/13/2024 08:30:00 AM                  25         TRAFFIC SIGNAL
# 923425  09/13/2023 01:08:00 PM                  30                UNKNOWN
#
#             DEVICE_CONDITION WEATHER_CONDITION      LIGHTING_CONDITION  \
# 923421           NO CONTROLS             CLEAR  DARKNESS, LIGHTED ROAD
# 923422  FUNCTIONING PROPERLY             CLEAR                DAYLIGHT
# 923423  FUNCTIONING PROPERLY             CLEAR  DARKNESS, LIGHTED ROAD
# 923424  FUNCTIONING PROPERLY             CLEAR                DAYLIGHT
# 923425               UNKNOWN           UNKNOWN                 UNKNOWN
#
#        FIRST_CRASH_TYPE                  TRAFFICWAY_TYPE  ...  \
# 923421         REAR END                      PARKING LOT  ...
# 923422         REAR END                         FOUR WAY  ...
# 923423       PEDESTRIAN                         FOUR WAY  ...
# 923424         REAR END  DIVIDED - W/MEDIAN (NOT RAISED)  ...
# 923425          TURNING                         FOUR WAY  ...
#
#         INJURIES_NON_INCAPACITATING INJURIES_REPORTED_NOT_EVIDENT  \
# 923421                          0.0                           0.0
# 923422                          0.0                           0.0
# 923423                          1.0                           0.0
# 923424                          0.0                           1.0
# 923425                          0.0                           0.0
#
#        INJURIES_NO_INDICATION INJURIES_UNKNOWN CRASH_HOUR CRASH_DAY_OF_WEEK  \
# 923421                    2.0              0.0         19                 4
# 923422                    2.0              0.0          9                 4
# 923423                    1.0              0.0         19                 4
# 923424                    1.0              0.0          8                 5
# 923425                    2.0              0.0         13                 4
#
#        CRASH_MONTH   LATITUDE  LONGITUDE  \
# 923421           1  41.988314 -87.791671
# 923422           1  41.852500 -87.666172
# 923423           1  41.885802 -87.624660
# 923424           6        NaN        NaN
# 923425           9  41.923913 -87.637409
#
#                                         LOCATION
# 923421  POINT (-87.791671453941 41.988313831775)
# 923422  POINT (-87.666172373715 41.852500328787)
# 923423  POINT (-87.624659771063 41.885801546318)
# 923424                                       NaN
# 923425  POINT (-87.637408804478 41.923913444256)
#
# [5 rows x 48 columns]

# %%
df.isna()
# Out:
#         CRASH_RECORD_ID  CRASH_DATE_EST_I  CRASH_DATE  POSTED_SPEED_LIMIT  \
# 0                 False              True       False               False
# 1                 False              True       False               False
# 2                 False              True       False               False
# 3                 False             False       False               False
# 4                 False              True       False               False
# ...                 ...               ...         ...                 ...
# 923421            False              True       False               False
# 923422            False              True       False               False
# 923423            False              True       False               False
# 923424            False              True       False               False
# 923425            False              True       False               False
#
#         TRAFFIC_CONTROL_DEVICE  DEVICE_CONDITION  WEATHER_CONDITION  \
# 0                        False             False              False
# 1                        False             False              False
# 2                        False             False              False
# 3                        False             False              False
# 4                        False             False              False
# ...                        ...               ...                ...
# 923421                   False             False              False
# 923422                   False             False              False
# 923423                   False             False              False
# 923424                   False             False              False
# 923425                   False             False              False
#
#         LIGHTING_CONDITION  FIRST_CRASH_TYPE  TRAFFICWAY_TYPE  ...  \
# 0                    False             False            False  ...
# 1                    False             False            False  ...
# 2                    False             False            False  ...
# 3                    False             False            False  ...
# 4                    False             False            False  ...
# ...                    ...               ...              ...  ...
# 923421               False             False            False  ...
# 923422               False             False            False  ...
# 923423               False             False            False  ...
# 923424               False             False            False  ...
# 923425               False             False            False  ...
#
#         INJURIES_NON_INCAPACITATING  INJURIES_REPORTED_NOT_EVIDENT  \
# 0                             False                          False
# 1                             False                          False
# 2                             False                          False
# 3                             False                          False
# 4                             False                          False
# ...                             ...                            ...
# 923421                        False                          False
# 923422                        False                          False
# 923423                        False                          False
# 923424                        False                          False
# 923425                        False                          False
#
#         INJURIES_NO_INDICATION  INJURIES_UNKNOWN  CRASH_HOUR  \
# 0                        False             False       False
# 1                        False             False       False
# 2                        False             False       False
# 3                        False             False       False
# 4                        False             False       False
# ...                        ...               ...         ...
# 923421                   False             False       False
# 923422                   False             False       False
# 923423                   False             False       False
# 923424                   False             False       False
# 923425                   False             False       False
#
#         CRASH_DAY_OF_WEEK  CRASH_MONTH  LATITUDE  LONGITUDE  LOCATION
# 0                   False        False     False      False     False
# 1                   False        False     False      False     False
# 2                   False        False      True       True      True
# 3                   False        False     False      False     False
# 4                   False        False     False      False     False
# ...                   ...          ...       ...        ...       ...
# 923421              False        False     False      False     False
# 923422              False        False     False      False     False
# 923423              False        False     False      False     False
# 923424              False        False      True       True      True
# 923425              False        False     False      False     False
#
# [923426 rows x 48 columns]

# %%
df = df.drop(columns=['CRASH_DATE_EST_I', 'LANE_CNT', 'INTERSECTION_RELATED_I', 'NOT_RIGHT_OF_WAY_I', 'PHOTOS_TAKEN_I', 'STATEMENTS_TAKEN_I', 'DOORING_I', 'WORK_ZONE_I', 'WORK_ZONE_TYPE', 'WORKERS_PRESENT_I'])
df.head()
# Out:
#                                      CRASH_RECORD_ID              CRASH_DATE  \
# 0  00a530520c84927490b597a6220ff3f2a3347472ef3086...  01/15/2025 01:50:00 PM
# 1  027187f52f9cac9ec542f1dda3a9ca8804db1fc2d2a386...  05/31/2020 01:13:00 AM
# 2  204c3ca48ff3cdf0737e7f10b54ef5f8c49fbe30b5e53e...  12/04/2024 05:39:00 PM
# 3  0173d218723a1d608d77b7142ca9b9a4afd7463e824162...  09/23/2023 10:39:00 AM
# 4  0386ef145c229cc3cb409c51d647b6496ab660104f16c7...  06/26/2023 01:54:00 PM
#
#    POSTED_SPEED_LIMIT TRAFFIC_CONTROL_DEVICE      DEVICE_CONDITION  \
# 0                  30            NO CONTROLS           NO CONTROLS
# 1                  30         TRAFFIC SIGNAL               UNKNOWN
# 2                  30                UNKNOWN               UNKNOWN
# 3                  30         TRAFFIC SIGNAL  FUNCTIONING PROPERLY
# 4                  30            NO CONTROLS  FUNCTIONING PROPERLY
#
#   WEATHER_CONDITION      LIGHTING_CONDITION      FIRST_CRASH_TYPE  \
# 0             CLEAR                DAYLIGHT          FIXED OBJECT
# 1             CLEAR  DARKNESS, LIGHTED ROAD               TURNING
# 2              RAIN  DARKNESS, LIGHTED ROAD               TURNING
# 3           UNKNOWN                 UNKNOWN  PARKED MOTOR VEHICLE
# 4             CLEAR                DAYLIGHT               TURNING
#
#     TRAFFICWAY_TYPE           ALIGNMENT  ... INJURIES_NON_INCAPACITATING  \
# 0              RAMP  STRAIGHT AND LEVEL  ...                         0.0
# 1          FOUR WAY  STRAIGHT AND LEVEL  ...                         0.0
# 2       NOT DIVIDED  STRAIGHT AND LEVEL  ...                         0.0
# 3       NOT DIVIDED  STRAIGHT AND LEVEL  ...                         0.0
# 4  CENTER TURN LANE  STRAIGHT AND LEVEL  ...                         0.0
#
#   INJURIES_REPORTED_NOT_EVIDENT INJURIES_NO_INDICATION INJURIES_UNKNOWN  \
# 0                           0.0                    1.0              0.0
# 1                           0.0                    4.0              0.0
# 2                           0.0                    2.0              0.0
# 3                           0.0                    1.0              0.0
# 4                           0.0                    3.0              0.0
#
#   CRASH_HOUR CRASH_DAY_OF_WEEK CRASH_MONTH   LATITUDE  LONGITUDE  \
# 0         13                 4           1  41.816073 -87.656743
# 1          1                 1           5  41.878326 -87.701280
# 2         17                 4          12        NaN        NaN
# 3         10                 7           9  42.010386 -87.670011
# 4         13                 2           6  41.873435 -87.666434
#
#                                    LOCATION
# 0  POINT (-87.656742699936 41.816073475493)
# 1  POINT (-87.701279794376 41.878326229569)
# 2                                       NaN
# 3   POINT (-87.67001097385 42.010385766289)
# 4    POINT (-87.666433681443 41.8734345658)
#
# [5 rows x 38 columns]

# %%
df.HIT_AND_RUN_I
# Out:
# 0         NaN
# 1           Y
# 2         NaN
# 3           Y
# 4         NaN
#          ...
# 923421      Y
# 923422    NaN
# 923423      Y
# 923424    NaN
# 923425    NaN
# Name: HIT_AND_RUN_I, Length: 923426, dtype: object

# %%
df['HIT_AND_RUN_I'] = df['HIT_AND_RUN_I'].fillna("Z")

# %%
df.HIT_AND_RUN_I
# Out:
# 0         Z
# 1         Y
# 2         Z
# 3         Y
# 4         Z
#          ..
# 923421    Y
# 923422    Z
# 923423    Y
# 923424    Z
# 923425    Z
# Name: HIT_AND_RUN_I, Length: 923426, dtype: object

# %%
num_rows_with_nan = df.isna().any(axis=1).sum()
print(num_rows_with_nan)
# Out:
# 37756

# %%
df=df.dropna()

# %%
num_rows_with_nan = df.isna().any(axis=1).sum()
print(num_rows_with_nan)
# Out:
# 0

# %%
duplicates = df[df.duplicated()]
print(duplicates)
# Out:
# Empty DataFrame
# Columns: [CRASH_RECORD_ID, CRASH_DATE, POSTED_SPEED_LIMIT, TRAFFIC_CONTROL_DEVICE, DEVICE_CONDITION, WEATHER_CONDITION, LIGHTING_CONDITION, FIRST_CRASH_TYPE, TRAFFICWAY_TYPE, ALIGNMENT, ROADWAY_SURFACE_COND, ROAD_DEFECT, REPORT_TYPE, CRASH_TYPE, HIT_AND_RUN_I, DAMAGE, DATE_POLICE_NOTIFIED, PRIM_CONTRIBUTORY_CAUSE, SEC_CONTRIBUTORY_CAUSE, STREET_NO, STREET_DIRECTION, STREET_NAME, BEAT_OF_OCCURRENCE, NUM_UNITS, MOST_SEVERE_INJURY, INJURIES_TOTAL, INJURIES_FATAL, INJURIES_INCAPACITATING, INJURIES_NON_INCAPACITATING, INJURIES_REPORTED_NOT_EVIDENT, INJURIES_NO_INDICATION, INJURIES_UNKNOWN, CRASH_HOUR, CRASH_DAY_OF_WEEK, CRASH_MONTH, LATITUDE, LONGITUDE, LOCATION]
# Index: []
#
# [0 rows x 38 columns]

# %%
df['CRASH_DATE'] = pd.to_datetime(df['CRASH_DATE'])
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8716\3047994292.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['CRASH_DATE'] = pd.to_datetime(df['CRASH_DATE'])

# %%
df['Crash Date'] = df['CRASH_DATE'].dt.date
df['Crash Time'] = df['CRASH_DATE'].dt.time
df
# Out:
#                                           CRASH_RECORD_ID          CRASH_DATE  \
# 0       00a530520c84927490b597a6220ff3f2a3347472ef3086... 2025-01-15 13:50:00
# 6       0235f4b4460f50115c7f6cb0d2bedeea7ce92b9b0f5943... 2025-01-15 18:40:00
# 12      03638af46c401466857cc6f4038eb6c992ede57917393f... 2025-01-15 09:57:00
# 13      04716502690d17e32815b04a038533b93e20290adf790f... 2025-01-15 19:30:00
# 14      0471a281311eab39c730a8afc45fbb5d43a5018b6742dd... 2025-01-15 20:15:00
# ...                                                   ...                 ...
# 923419  969bd7fa2d19eabbaeb5e7e25124087945cfd99a4e32a2... 2025-01-27 07:00:00
# 923420  5f3265aec2ae9cb1e601fe0a0b4af11191b55d8786a26c... 2025-01-28 15:50:00
# 923421  00580c38c361fe6da401a2a6b96f381a08f3a6811f18c7... 2025-01-29 19:25:00
# 923422  4f4333f00f578df2ffc68daa7a1177143340d8d899b83c... 2025-01-29 09:27:00
# 923423  5ac09423aa9016c9755f1cace10a067fcab2648f18577c... 2025-01-29 19:08:00
#
#         POSTED_SPEED_LIMIT TRAFFIC_CONTROL_DEVICE      DEVICE_CONDITION  \
# 0                       30            NO CONTROLS           NO CONTROLS
# 6                       25         TRAFFIC SIGNAL  FUNCTIONING PROPERLY
# 12                      30            NO CONTROLS           NO CONTROLS
# 13                      30         TRAFFIC SIGNAL  FUNCTIONING PROPERLY
# 14                      10            NO CONTROLS           NO CONTROLS
# ...                    ...                    ...                   ...
# 923419                  30            NO CONTROLS           NO CONTROLS
# 923420                  40            NO CONTROLS           NO CONTROLS
# 923421                  30            NO CONTROLS           NO CONTROLS
# 923422                  30         TRAFFIC SIGNAL  FUNCTIONING PROPERLY
# 923423                  30         TRAFFIC SIGNAL  FUNCTIONING PROPERLY
#
#        WEATHER_CONDITION      LIGHTING_CONDITION          FIRST_CRASH_TYPE  \
# 0                  CLEAR                DAYLIGHT              FIXED OBJECT
# 6                  CLEAR  DARKNESS, LIGHTED ROAD                     ANGLE
# 12                 CLEAR                DAYLIGHT                  REAR END
# 13                 CLEAR  DARKNESS, LIGHTED ROAD                   TURNING
# 14                 CLEAR  DARKNESS, LIGHTED ROAD      PARKED MOTOR VEHICLE
# ...                  ...                     ...                       ...
# 923419             CLEAR                DAYLIGHT  SIDESWIPE SAME DIRECTION
# 923420             CLEAR                DAYLIGHT  SIDESWIPE SAME DIRECTION
# 923421             CLEAR  DARKNESS, LIGHTED ROAD                  REAR END
# 923422             CLEAR                DAYLIGHT                  REAR END
# 923423             CLEAR  DARKNESS, LIGHTED ROAD                PEDESTRIAN
#
#                    TRAFFICWAY_TYPE           ALIGNMENT  ...  \
# 0                             RAMP  STRAIGHT AND LEVEL  ...
# 6                         FOUR WAY  STRAIGHT AND LEVEL  ...
# 12                     NOT DIVIDED  STRAIGHT AND LEVEL  ...
# 13                     NOT DIVIDED  STRAIGHT AND LEVEL  ...
# 14                     PARKING LOT  STRAIGHT AND LEVEL  ...
# ...                            ...                 ...  ...
# 923419                 NOT DIVIDED  STRAIGHT AND LEVEL  ...
# 923420  DIVIDED - W/MEDIAN BARRIER  STRAIGHT AND LEVEL  ...
# 923421                 PARKING LOT  STRAIGHT AND LEVEL  ...
# 923422                    FOUR WAY  STRAIGHT AND LEVEL  ...
# 923423                    FOUR WAY  STRAIGHT AND LEVEL  ...
#
#        INJURIES_NO_INDICATION INJURIES_UNKNOWN CRASH_HOUR CRASH_DAY_OF_WEEK  \
# 0                         1.0              0.0         13                 4
# 6                         2.0              0.0         18                 4
# 12                        1.0              0.0          9                 4
# 13                        4.0              0.0         19                 4
# 14                        1.0              0.0         20                 4
# ...                       ...              ...        ...               ...
# 923419                    2.0              0.0          7                 2
# 923420                    2.0              0.0         15                 3
# 923421                    2.0              0.0         19                 4
# 923422                    2.0              0.0          9                 4
# 923423                    1.0              0.0         19                 4
#
#        CRASH_MONTH   LATITUDE  LONGITUDE  \
# 0                1  41.816073 -87.656743
# 6                1  41.846038 -87.724761
# 12               1  41.967763 -87.760295
# 13               1  41.829775 -87.704754
# 14               1  41.941566 -87.668860
# ...            ...        ...        ...
# 923419           1  41.883098 -87.633134
# 923420           1  41.903788 -87.624720
# 923421           1  41.988314 -87.791671
# 923422           1  41.852500 -87.666172
# 923423           1  41.885802 -87.624660
#
#                                         LOCATION  Crash Date  Crash Time
# 0       POINT (-87.656742699936 41.816073475493)  2025-01-15    13:50:00
# 6       POINT (-87.724761370522 41.846037568964)  2025-01-15    18:40:00
# 12      POINT (-87.760294815479 41.967763049214)  2025-01-15    09:57:00
# 13      POINT (-87.704753514706 41.829774959784)  2025-01-15    19:30:00
# 14      POINT (-87.668860402909 41.941565857782)  2025-01-15    20:15:00
# ...                                          ...         ...         ...
# 923419   POINT (-87.633134156843 41.88309798438)  2025-01-27    07:00:00
# 923420  POINT (-87.624720160474 41.903788026488)  2025-01-28    15:50:00
# 923421  POINT (-87.791671453941 41.988313831775)  2025-01-29    19:25:00
# 923422  POINT (-87.666172373715 41.852500328787)  2025-01-29    09:27:00
# 923423  POINT (-87.624659771063 41.885801546318)  2025-01-29    19:08:00
#
# [885670 rows x 40 columns]

# %%
df['DATE_POLICE_NOTIFIED'] = pd.to_datetime(df['DATE_POLICE_NOTIFIED'])
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8716\451310334.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['DATE_POLICE_NOTIFIED'] = pd.to_datetime(df['DATE_POLICE_NOTIFIED'])

# %%
df['Police Notified Date'] = df['DATE_POLICE_NOTIFIED'].dt.date
df['Police Notified Time'] = df['DATE_POLICE_NOTIFIED'].dt.time
df

# %%
unique_values=df['TRAFFICWAY_TYPE'].unique()
print(unique_values)

# %%
df = df.drop(columns=['CRASH_DATE', 'DATE_POLICE_NOTIFIED'])
df.head()

# %%
df.to_csv("clean_chicago_traffic.csv", index=False)

# %%
print(df.columns)
